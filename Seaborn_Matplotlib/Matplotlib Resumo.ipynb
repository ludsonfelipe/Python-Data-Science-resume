# %% [markdown]
# # Plotagem Rápida
# <p> O matplotlib nos oferece um recurso muito bom para visualização de dados de maneira rápida que é a plotagem rápida de gráficos com comandos curtos </p>
#
# ![Matplotlib1.png](attachment:Matplotlib1.png)

# %% [markdown]
# ## Prametros Uteis
# ```python
#     Type1
#     # plt.xlabel
#     # plt.ylabel
#     # plt.title
#     # plt.yticks
#     # plt.show
#
#     Type2
#     # df.plot( rot = 45 )
#     # df.plot( marker = ...)
#     # df.plot( title = ...)
# ```

# %% [markdown]
# # Plotagem Rebuscada
# <p> Para gráfico que possam necessitar de maior modificação podemos utilizar a plotagem dinâmica, que nos permite criar dashboards bem completos e rebuscados </p>
#
# ![Matplotlib2.png](attachment:Matplotlib2.png)

# %% [markdown]
# <p> Além disso podemos colocar dois gráficos ocupando o mesmo subplot </p>
#
# ![Matplotlib3.png](attachment:Matplotlib3.png)

# %% [markdown]
# ## Parametross úteis
# ```python
#
#     # ax.plot(x, y, marker = ...)
#     # ax.plot(x, y, linestyle = ... )
#     # ax.plot(x, y, color = ... )
#
#     # ax.bar(bottom = ...)
#     # ax.hist(histtype = "step")
#     # ax.bar(yerr = ...)
#     # ax.scatter(label = )
#     # ax.boxplot()
#
#     # ax.set_xlabel(...)
#     # ax.set_xticklabels( rotation = 90 )
#     # ax.set_title(...)
#     # ax.tick_params('y', colors='red')
#     # ax.legend()
#
# ```

# %% [markdown]
# <p> Ou dividir os eixos para dois tipos de gráfico diferentes </p>
#
# ![Matplotlib4.png](attachment:Matplotlib4.png)

# %% [markdown]
# # SAVE FIG

# %% [markdown]
# <p> Para salvar nossas figuras, alterar tamanho e fazer outras modificações podemos simplismente usar os seguintes comandos </p>
#
# ![matplotlib5.png](attachment:matplotlib5.png)

# %% [markdown]
# ![Matplotlib6.png](attachment:Matplotlib6.png)
